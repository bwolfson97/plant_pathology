# %% [markdown]
# # MixUp

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from plant_pathology.all import *

# %% [markdown]
# ## Train Model

# %%
# %%capture output
learn = train(180, 2e-2, frz=20, pre=500, re=256, bs=256, fold=4, smooth=False, arch='resnet18', mixup=0.4)

# %%
output.show()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.873095</td>
#       <td>0.907237</td>
#       <td>0.750000</td>
#       <td>0.820836</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.594394</td>
#       <td>0.986225</td>
#       <td>0.777473</td>
#       <td>0.869268</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.505809</td>
#       <td>1.263266</td>
#       <td>0.717033</td>
#       <td>0.906118</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.323676</td>
#       <td>0.726712</td>
#       <td>0.796703</td>
#       <td>0.881128</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %% [markdown]
# ## Evaluate

# %%
submission_path = evaluate(learn)

# %%
kaggle_submit_command()
# Out:
# !kaggle competitions submit -c plant-pathology-2020-fgvc7 -f {submission_path} -m 'hi'

# %%
# !kaggle competitions submit -c plant-pathology-2020-fgvc7 -f {submission_path} -m 'mixup-200-epochs'
# Out:
# ...
# 100%|██████████████████████████████████████| 92.7k/92.7k [00:02<00:00, 44.5kB/s]
# Successfully submitted to Plant Pathology 2020 - FGVC7
